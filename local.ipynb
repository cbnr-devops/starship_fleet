# %%
import requests                                                                                                                                      
                
url = "http://20.92.178.62/starfleet/starship"     

for i in range(1,9):
    response = requests.post(url, json={"id": i})

# %%
resp.text
# Out:
# '{"detail":"Not Found"}'
